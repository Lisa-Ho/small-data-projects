# %%
import tweepy
import configparser
import datetime
import pandas as pd

# %%
datetime.datetime.today()
# Out:
# datetime.datetime(2023, 6, 3, 13, 16, 43, 84946)

# %%
#get API credentials
config = configparser.ConfigParser()
config.read("credentials.cfg")
bearer_token = config["Twitter API"]["bearer_token"]

# %%
client = tweepy.Client(bearer_token=bearer_token)

# %%
query = '#Caturday -is:retweet lang:en'
#tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
paginator = tweepy.Paginator(client.search_recent_tweets, query=query, tweet_fields=['context_annotations', 'created_at'], max_results=10).flatten(100)

# %%
query = '#Caturday -is:retweet lang:en'
#tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
paginator = tweepy.Paginator(client.search_recent_tweets, query=query, tweet_fields=['context_annotations', 'created_at'], place_fields=['name', 'place_type'] ,
                             expansions="geo.place_id", max_results=10).flatten(100)

# %%
data = {"text": [], "created_at": [], "context":[]}

for response in paginator:
    data["text"].append(response.text)
    data["created_at"].append(response.created_at)
    if len(response.context_annotations) > 0:
        data["context"].append(response.context_annotations)
    else:
        data["context"].append("")

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#                                                  text  \
# 0   New pipe cleaners for #Caturday with #KermitTh...
# 1   @CSurvivor9 IN the MODE . . . \n\n Enjoy your ...
# 2   Every cat is already a cat gang in its own rig...
# 3   @myboringjourne2 Happy #Caturday, Forrest❤️😽 h...
# 4   Happy Caturday 🐱 😊\n\n#Caturday https://t.co/B...
# ..                                                ...
# 94  Caturday, a haiku.\n\nCaturday is here\nTime t...
# 95  @NinaIvAndrews @claudia_oltean @ReadingIsOurPa...
# 96  Current mood for #Caturday is love ❤️be sure t...
# 97  Happy Caturday from our Caturday Champion Tamm...
# 98  Happy #Caturday from these two beauties ❤️ htt...
#
#                   created_at  \
# 0  2023-06-03 12:34:22+00:00
# 1  2023-06-03 12:34:17+00:00
# 2  2023-06-03 12:33:49+00:00
# 3  2023-06-03 12:33:45+00:00
# 4  2023-06-03 12:33:39+00:00
# ..                       ...
# 94 2023-06-03 12:13:43+00:00
# 95 2023-06-03 12:13:41+00:00
# 96 2023-06-03 12:13:20+00:00
# ...

# %%
for response in paginator:
    response.includes.get('places')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 2
#       1 for response in paginator:
# ----> 2     response.includes.get('places')
#
# File c:\Users\lisa.hornung\anaconda3\envs\twitter\Lib\site-packages\tweepy\mixins.py:35, in DataMapping.__getattr__(self, name)
#      33     return self.data[name]
#      34 except KeyError:
# ---> 35     raise AttributeError from None
#
# AttributeError:

# %%
tweets
# Out:
# <generator object Paginator.flatten at 0x0000019D2916ACE0>

# %%
len(text)
# Out:
# 2987

# %%
text
# Out:
# ['Train strikes will not effect fans travelling from their home to Wembley today for the FA Cup Final as the London Underground services are as normal',
#  'Was planning a spontaneous trip to Kidderminster, but there are bloody train strikes. Humph.',
#  '@Chrissy_Chriis Train strikes always ruining things 😩',
#  '@habibi_uk Well considering public support for the train strikes is at an all time low, this will not help them. Time for the RMT to be proscribed.',
#  "As train strikes across several networks continue today, what's the best way to get around London?  https://t.co/aNY02ZXLFO",
#  '@AjinkyarJadhav Tragedy Strikes as Train Derails https://t.co/1rFlVJw7RW',
#  'Chaos on the way to Wembley as there is a signal failure on the Metropolitan Line. Full trains of fans thrown off and told to walk to Baker Street. Just what we all needed after the train strikes!',
# ...

# %%
datetime.datetime(2023, 6,2, 0, 0, 0)
datetime.datetime(2023, 6,2, 23, 59, 59)
# Out:
# datetime.datetime(2023, 6, 2, 23, 59, 59)
